# %% [markdown]
# <a href="https://colab.research.google.com/github/munozfloresnelsont12-oss/PPIA-github/blob/main/AF1_Nelson_Tadeo_Mu%C3%B1oz_Flores_2227010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***EJERCICIO 1.- USO DE PANDAS, MATPLOTLIB, NUMPY.***

# %% [markdown]
# EJERCICIO 1.1.- LIMPIEZA Y MANIPULACION CON PANDAS.

# %%
# IMPORTAR LAS LIBRERIAS.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1. IMPORTAR EL DATASET DESDE UNA URL.
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
df = pd.read_csv(url, sep=';')

print("¡Dataset cargado con éxito!")
# Out:
# ¡Dataset cargado con éxito!

# %%
#2. MUESTRA LAS PRIMERAS 5 FILAS Y EL RESUMEN ESTADISTICO.
print(df.head())
df.describe()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
#3. IDENTIFICA SI HAY VALORES NULOS Y ELIMINALOS.
print(df.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#4. CREA UNA NUEVA COLUMNA LLAMADA IS_GOOD QUE SEA 1 SI LA QUALITY ES MAYOR A 6, Y 0 EN CASO CONTRARIO.
df['is_good'] = np.where(df['quality'] > 6, 1, 0)
print("DataFrame con la nueva columna 'is_good':")
display(df.head())
# Out:
# DataFrame con la nueva columna 'is_good':
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  is_good
# 0      9.4        5        0
# 1      9.8        5        0
# 2      9.8        5        0
# 3      9.8        6        0
# 4      9.4        5        0

# %%
#5. FILTRA EL DATAFRAME PARA MOSTRAR SOLO LOS VINOS CON UN NIVEL DE ALCOHOL SUPERIOR AL 11%.
df_AlcoholSuperior = df[df['alcohol'] > 11]
df_AlcoholSuperior.shape
# Out:
# (408, 13)

# %% [markdown]
# EJERCICIO 1.2.-OPERACIONES MATEMATICAS CON NUMPY.

# %%
#1. CONVIERTE LAS COLUMNAS DE CARACTERISTICAS (FEATURES) EN UNA MATRIZ DE NUMPY LLAMADA X.
X = df.drop(columns=['quality', 'is_good']).values
print("Forma de X:", X.shape)
print("Primeras 5 filas de X:\n", X[:5])
# Out:
# Forma de X: (1599, 11)
# Primeras 5 filas de X:
#  [[7.400e+00 7.000e-01 0.000e+00 1.900e+00 7.600e-02 1.100e+01 3.400e+01
#   9.978e-01 3.510e+00 5.600e-01 9.400e+00]
#  [7.800e+00 8.800e-01 0.000e+00 2.600e+00 9.800e-02 2.500e+01 6.700e+01
#   9.968e-01 3.200e+00 6.800e-01 9.800e+00]
#  [7.800e+00 7.600e-01 4.000e-02 2.300e+00 9.200e-02 1.500e+01 5.400e+01
#   9.970e-01 3.260e+00 6.500e-01 9.800e+00]
#  [1.120e+01 2.800e-01 5.600e-01 1.900e+00 7.500e-02 1.700e+01 6.000e+01
#   9.980e-01 3.160e+00 5.800e-01 9.800e+00]
#  [7.400e+00 7.000e-01 0.000e+00 1.900e+00 7.600e-02 1.100e+01 3.400e+01
#   9.978e-01 3.510e+00 5.600e-01 9.400e+00]]

# %%
#2. CALCULA LA MEDIA Y LA DESVIACION ESTANDAR DE CADA COLUMNA UTILIZANDO UNICAMENTE FUNCIONES DE NUMPY.
mean_X = np.mean(X, axis=0)
std_X = np.std(X, axis=0)

print("Media de cada columna de X:\n", mean_X)
print("Desviación estándar de cada columna de X:\n", std_X)
# Out:
# Media de cada columna de X:
#  [ 8.31963727  0.52782051  0.27097561  2.5388055   0.08746654 15.87492183
#  46.46779237  0.99674668  3.3111132   0.65814884 10.42298311]
# Desviación estándar de cada columna de X:
#  [1.74055180e+00 1.79003704e-01 1.94740214e-01 1.40948711e+00
#  4.70505826e-02 1.04568856e+01 3.28850367e+01 1.88674370e-03
#  1.54338181e-01 1.69453967e-01 1.06533430e+00]

# %%
#3. NORMALIZACION Z CORE: IMPLEMENTA MANUALMENTE LA FORMULA PARA NORMALIZAR LOS DATOS.
X_normalized = (X - mean_X) / std_X
print("Primeras 5 filas de X normalizada:\n", X_normalized[:5])
# Out:
# Primeras 5 filas de X normalizada:
#  [[-0.52835961  0.96187667 -1.39147228 -0.45321841 -0.24370669 -0.46619252
#   -0.37913269  0.55827446  1.28864292 -0.57920652 -0.96024611]
#  [-0.29854743  1.96744245 -1.39147228  0.04341614  0.2238752   0.87263823
#    0.62436323  0.02826077 -0.7199333   0.1289504  -0.58477711]
#  [-0.29854743  1.29706527 -1.18607043 -0.16942723  0.09635286 -0.08366945
#    0.22904665  0.13426351 -0.33117661 -0.04808883 -0.58477711]
#  [ 1.65485608 -1.38444349  1.4841536  -0.45321841 -0.26496041  0.10759209
#    0.41150046  0.6642772  -0.97910442 -0.46118037 -0.58477711]
#  [-0.52835961  0.96187667 -1.39147228 -0.45321841 -0.24370669 -0.46619252
#   -0.37913269  0.55827446  1.28864292 -0.57920652 -0.96024611]]

# %% [markdown]
# EJERCICIO 1.3.- VISUALIZACION DE INSIGHTS CON MATPLOTLIB.

# %%
#1. CREA UN HISTOGRAMA DE LA VARIABLE ALCOHOL PARA VER SU DISTRIBUCION.
plt.figure(figsize=(8, 6))
plt.hist(df['alcohol'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribución del Contenido de Alcohol')
plt.xlabel('Alcohol (%)')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
#2. REALIZA UN GRAFICO DE DISPERSION ENTRE PH Y FIXED ACIDITY.
plt.figure(figsize=(10, 6))
plt.scatter(df['pH'], df['fixed acidity'], alpha=0.5, color='purple')
plt.title('Relación entre pH y Acidez Fija')
plt.xlabel('pH')
plt.ylabel('Acidez Fija')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
#3. GENERA UN GRAFICO DE CAJAS QUE COMPARE EL NIVEL DE ALCOHOL SEGUN EL VALOR DE LA COLUMNA QUALITY.
plt.figure(figsize=(10, 6))
plt.boxplot([df['alcohol'][df['quality'] == q] for q in sorted(df['quality'].unique())], labels=sorted(df['quality'].unique()))
plt.title('Nivel de Alcohol por Calidad del Vino')
plt.xlabel('Calidad del Vino')
plt.ylabel('Alcohol (%)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipykernel_20015/1820490888.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df['alcohol'][df['quality'] == q] for q in sorted(df['quality'].unique())], labels=sorted(df['quality'].unique()))

# %% [markdown]
# ***EJERCICIO 2.- USO DE PANDAS, MATPLOTLIB, NUMPY.***

# %% [markdown]
# EJERCICIO 2.1.- ANALISIS EXPLORATORIO CON PANDAS.

# %%
#CARGAR LIBRERIAS.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1. CARGAR EL DATASET DE PINGUINOS DE PALMER.
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
df = pd.read_csv(url)
print("¡Dataset cargado correctamente!")
# Out:
# ¡Dataset cargado correctamente!

# %%
#2. IDENTIFICA CUANTAS FILAS TIENEN VALORES NAN. ELILIMA AQUELLAS FILAS DONDE FALTEN DATOS CRITICOS(COMO EL PESO O EL TAMAÑO DE EQUIPO).
print("Valores NaN por columna antes de la eliminación:")
print(df.isnull().sum())
critical_columns = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
rows_with_nan_in_critical = df[df[critical_columns].isnull().any(axis=1)]
print(f"\nNúmero de filas con NaN en columnas críticas: {len(rows_with_nan_in_critical)}")
df_cleaned = df.dropna(subset=critical_columns)
print(f"\nForma del DataFrame antes de la eliminación: {df.shape}")
print(f"Forma del DataFrame después de la eliminación: {df_cleaned.shape}")
# Out:
# Valores NaN por columna antes de la eliminación:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64
#
# Número de filas con NaN en columnas críticas: 2
#
# Forma del DataFrame antes de la eliminación: (344, 7)
# Forma del DataFrame después de la eliminación: (342, 7)

# %%
df = df_cleaned.copy()

# %%
#3. AGRUPACION: CALCULA LA MASA CORPORAL (BODY_MASS_G) PROMEDIO POR CADA ESPECIE Y POR ISLA.
average_body_mass = df.groupby(['species', 'island'])['body_mass_g'].mean().reset_index()
print("Masa corporal promedio por especie y por isla:")
display(average_body_mass)
# Out:
# Masa corporal promedio por especie y por isla:
#      species     island  body_mass_g
# 0     Adelie     Biscoe  3709.659091
# 1     Adelie      Dream  3688.392857
# 2     Adelie  Torgersen  3706.372549
# 3  Chinstrap      Dream  3733.088235
# 4     Gentoo     Biscoe  5076.016260

# %%
#4.CREA UN SUBCONJUNTO DE DATOS QUE SOLO CONTENGA A LOS PINGUINOS DE LA ESPECIE GENTOO QUE PESEN MAS DE 5000G.
gentoo_heavy_penguins = df[(df['species'] == 'Gentoo') & (df['body_mass_g'] > 5000)]
print("Pingüinos 'Gentoo' con masa corporal mayor a 5000g:")
display(gentoo_heavy_penguins.head())
print(f"\nNúmero de pingüinos 'Gentoo' que pesan más de 5000g: {gentoo_heavy_penguins.shape[0]}")
# Out:
# Pingüinos 'Gentoo' con masa corporal mayor a 5000g:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# 227  Gentoo  Biscoe            46.7           15.3              219.0
# 229  Gentoo  Biscoe            46.8           15.4              215.0
#
#      body_mass_g   sex
# 221       5700.0  MALE
# 223       5700.0  MALE
# 224       5400.0  MALE
# 227       5200.0  MALE
# 229       5150.0  MALE
# Número de pingüinos 'Gentoo' que pesan más de 5000g: 61

# %% [markdown]
# EJERCICIO 2.2.- PROCESAMIENTO DE SEÑALES CON NUMPY.

# %%
#1. EXTRAE LAS COLUMNAS BILL_LENGTH_MM (LARGO) Y BILL_DEPTH_MM (ALTO) Y CONVIERTELAS EN UNA MATRIZ DE NUMPY DE N X 2.
bill_dimensions_df = df[['bill_length_mm', 'bill_depth_mm']]
bill_dimensions_np = bill_dimensions_df.values
print("Primeros 5 registros de la matriz NumPy:")
print(bill_dimensions_np[:5])
print(f"\nForma de la matriz NumPy: {bill_dimensions_np.shape}")
# Out:
# Primeros 5 registros de la matriz NumPy:
# [[39.1 18.7]
#  [39.5 17.4]
#  [40.3 18. ]
#  [36.7 19.3]
#  [39.3 20.6]]
#
# Forma de la matriz NumPy: (342, 2)

# %%
#2. CREA UN NUEVO ARRAY QUE SEA EL RESULTADO DE DIVIDIR ENTRE EL ALTO PARA CADA PINGUINO.
bill_proportion_np = bill_dimensions_np[:, 0] / bill_dimensions_np[:, 1]
print("Primeros 5 registros del array de proporciones:")
print(bill_proportion_np[:5])
print(f"\nForma del array de proporciones: {bill_proportion_np.shape}")
# Out:
# Primeros 5 registros del array de proporciones:
# [2.09090909 2.27011494 2.23888889 1.9015544  1.90776699]
#
# Forma del array de proporciones: (342,)

# %%
#3. UTILIZA UNA FUNCION DE NUMPY PARA ENCONTRAR QUE PINGUINOS TIENEN UN LARGO DE PICO QUE ESTE A MAS DE 2 DESVIACIONES ESTANDAR DE LA MEDIA DEL GRUPO.
bill_length = df['bill_length_mm'].values

# Calcular la media y la desviación estándar del largo del pico
mean_bill_length = np.mean(bill_length)
std_bill_length = np.std(bill_length)

# Definir los límites para la detección de outliers (2 desviaciones estándar)
upper_bound = mean_bill_length + 2 * std_bill_length
lower_bound = mean_bill_length - 2 * std_bill_length

# Encontrar los pingüinos que son outliers
outlier_indices = np.where((bill_length > upper_bound) | (bill_length < lower_bound)) # Aquí el símbolo "|" significa "or"
outlier_penguins = df.iloc[outlier_indices]

print(f"Media del largo del pico: {mean_bill_length:.2f} mm")
print(f"Desviación estándar del largo del pico: {std_bill_length:.2f} mm")
print(f"Límite superior (media + 2*std): {upper_bound:.2f} mm")
print(f"Límite inferior (media - 2*std): {lower_bound:.2f} mm")

print(f"\nNúmero de pingüinos con largo de pico a más de 2 desviaciones estándar: {len(outlier_penguins)}")
print("\nPingüinos considerados outliers por el largo del pico:")
display(outlier_penguins)
# Out:
# Media del largo del pico: 43.92 mm
# Desviación estándar del largo del pico: 5.45 mm
# Límite superior (media + 2*std): 54.83 mm
# Límite inferior (media - 2*std): 33.02 mm
#
# Número de pingüinos con largo de pico a más de 2 desviaciones estándar: 6
#
# Pingüinos considerados outliers por el largo del pico:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 142     Adelie   Dream            32.1           15.5              188.0
# 169  Chinstrap   Dream            58.0           17.8              181.0
# 215  Chinstrap   Dream            55.8           19.8              207.0
# 253     Gentoo  Biscoe            59.6           17.0              230.0
# 321     Gentoo  Biscoe            55.9           17.0              228.0
# 335     Gentoo  Biscoe            55.1           16.0              230.0
#
#      body_mass_g     sex
# 142       3050.0  FEMALE
# 169       3700.0  FEMALE
# 215       4000.0    MALE
# 253       6050.0    MALE
# 321       5600.0    MALE
# 335       5850.0    MALE

# %%
#4. EXTRAE SOLO LOS DATOS DE LLOS PINGUINOS QUE ESTAN EN LAS POSICIONES PARES DEL ARRAY ORIGINAL.
even_indexed_penguins = df.iloc[::2]

print("Primeros 5 registros de los pingüinos con índices pares:")
display(even_indexed_penguins.head())

print(f"\nNúmero de pingüinos con índices pares: {len(even_indexed_penguins)}")
# Out:
# Primeros 5 registros de los pingüinos con índices pares:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 2       3250.0  FEMALE
# 5       3650.0    MALE
# 7       4675.0    MALE
# 9       4250.0     NaN
# Número de pingüinos con índices pares: 171

# %% [markdown]
# EJERCICIO 2.3.- VISUALIZACION CIENTIFICA CON MATPLOTLIB.

# %%
#1. GRAFICA FLIPPER_LENGTH_MM (ALETAS) EN EL EJE X Y BODY_MASS_G EN EL EJE Y.
plt.figure(figsize=(10, 6))
plt.scatter(df['flipper_length_mm'], df['body_mass_g'])
plt.xlabel('Longitud de Aleta (mm)')
plt.ylabel('Masa Corporal (g)')
plt.title('Relación entre Longitud de Aleta y Masa Corporal de Pingüinos')
plt.grid(True)
plt.show()

# %%
#2. USA UN COLOR DIFERENTE PARA CADA UNA DE LAS TRES ESPECIES, ESTO AYUDA A VER COMO SE AGRUPAN NATURALMENTE.
species_list = df['species'].unique()
colors = plt.cm.get_cmap('viridis', len(species_list))

for i, species in enumerate(species_list):
    subset = df[df['species'] == species]
    plt.scatter(subset['flipper_length_mm'], subset['body_mass_g'],
                color=colors(i), label=species)

plt.xlabel('Longitud de Aleta (mm)')
plt.ylabel('Masa Corporal (g)')
plt.title('Relación entre Longitud de Aleta y Masa Corporal de Pingüinos por Especie')
plt.grid(True)
plt.legend(title='Especie')
plt.show()
# Out:
# /tmp/ipykernel_20015/3959783410.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('viridis', len(species_list))

# %%
#3. AÑADE UNA FLECHA O UN TEXTO EN EL GRAFICO SEÑALANDO AL PINGUINO MAS PESADO DEL DATASET.
heaviest_penguin = df.loc[df['body_mass_g'].idxmax()]

heaviest_x = heaviest_penguin['flipper_length_mm']
heaviest_y = heaviest_penguin['body_mass_g']
heaviest_species = heaviest_penguin['species']

plt.figure(figsize=(10, 6))

species_list = df['species'].unique()
colors = plt.cm.get_cmap('viridis', len(species_list))

for i, species in enumerate(species_list):
    subset = df[df['species'] == species]
    plt.scatter(subset['flipper_length_mm'], subset['body_mass_g'],
                color=colors(i), label=species)

plt.annotate(f'El más pesado: {heaviest_y:.0f}g ({heaviest_species})',
             xy=(heaviest_x, heaviest_y),
             xytext=(heaviest_x + 10, heaviest_y + 200),
             arrowprops=dict(facecolor='black', shrink=0.05),
             ha='center',
             fontsize=10,
             bbox=dict(boxstyle="round,pad=0.3", fc="yellow", ec="b", lw=1, alpha=0.7))

plt.xlabel('Longitud de Aleta (mm)')
plt.ylabel('Masa Corporal (g)')
plt.title('Relación entre Longitud de Aleta y Masa Corporal de Pingüinos por Especie (con Anotación)')
plt.grid(True)
plt.legend(title='Especie')
plt.show()
# Out:
# /tmp/ipykernel_20015/1518646195.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('viridis', len(species_list))

# %%
#4. CREA UNA FIGURA CON DOS SUBPLOTS (GRAFICOS UNO AL LADO DEL OTRO): UNO CON LA MASA CORPORAL Y OTRO CON EL TAMAÑO DE LAS ALETAS.
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

axes[0].hist(df['body_mass_g'].dropna(), bins=20, color='skyblue', edgecolor='black')
axes[0].set_title('Distribución de la Masa Corporal (g)')
axes[0].set_xlabel('Masa Corporal (g)')
axes[0].set_ylabel('Frecuencia')
axes[0].grid(axis='y', alpha=0.75)

axes[1].hist(df['flipper_length_mm'].dropna(), bins=20, color='lightcoral', edgecolor='black')
axes[1].set_title('Distribución de la Longitud de Aleta (mm)')
axes[1].set_xlabel('Longitud de Aleta (mm)')
axes[1].set_ylabel('Frecuencia')
axes[1].grid(axis='y', alpha=0.75)

plt.tight_layout()
plt.show()
