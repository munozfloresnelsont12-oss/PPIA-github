# %% [markdown]
# <a href="https://colab.research.google.com/github/munozfloresnelsont12-oss/PPIA-github/blob/main/PRIMERNOTEBOOK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("¡hola mundo!")
# Out:
# ¡hola mundo!
